# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd /content/drive/MyDrive/newcode
# Out:
# /content/drive/MyDrive/Final_Project/DATN/CRAWLER/schema

# %%
pip install recordlinkage
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 926.9/926.9 kB 11.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 19.1 MB/s eta 0:00:00
# ...

# %%
import pandas as pd
import recordlinkage

# %%
dataset = pd.read_csv(" b/all_dataset_after_schema-matching.csv")

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20644 entries, 0 to 20643
# Data columns (total 23 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   title          20643 non-null  object
#  1   description    20644 non-null  object
#  2   price          20644 non-null  float64
#  3   square         20643 non-null  object
#  4   type           20644 non-null  int64
#  5   name_contact   19103 non-null  object
#  6   phone_contact  19103 non-null  object
#  7   date           19103 non-null  object
#  8   direct         19347 non-null  object
#  9   district       20644 non-null  object
#  10  province       20643 non-null  object
#  11  street         20644 non-null  object
#  12  ward           20644 non-null  object
#  13  floor          20644 non-null  object
#  14  juridical      20643 non-null  object
#  15  bedroom        20644 non-null  object
#  16  length         20643 non-null  object
# ...

# %%
indexer = recordlinkage.Index()
indexer.full()
candidates = indexer.index(dataset)
# Out:
# WARNING:recordlinkage:indexing - performance warning - A full index can result in large number of record pairs.
# WARNING:recordlinkage:indexing - performance warning - A full index can result in large number of record pairs.

# %%
len(candidates)
# Out:
# 213077046

# %%
indexer = recordlinkage.Index()
indexer.block("square")
candidates = indexer.index(dataset)

# %%
len(candidates)
# Out:
# 1829298

# %%
compare_cl = recordlinkage.Compare()
compare_cl.string("title", "title", method="levenshtein", threshold=0.85, label="title")
compare_cl.string("description", "description", method="levenshtein", threshold=0.7, label="title")
# compare_cl.string("direct", "direct", method="levenshtein", threshold=0.9, label="title")
compare_cl.exact("province", "province", label="province")
# compare_cl.exact("street", "street", label="street")
# compare_cl.exact("floor", "floor", label="floor")

features = compare_cl.compute(candidates, dataset)

# %%
matches = features[features.sum(axis=1) == 3]

# %%
cnt = 0
for i in range(len(matches.index)):
    # print(dataset.iloc[matches.index[i][0]]['url_page'])
    # if "bds123" in dataset.iloc[matches.index[i][1]]['url_page'] and "batdongsan" in dataset.iloc[matches.index[i][0]]['url_page']:
      print(dataset.iloc[matches.index[i][0]]['url_page'])
      print("---------------------------------------------")
      print(dataset.iloc[matches.index[i][1]]['url_page'])
      print("+++++++++++++++++++++++++++++++++++++++++++++")
      cnt += 1
      # if cnt == 100:
      #   break
# Out:
# https://nhadat24h.net.vn/du-an/ph0301-hoang-trong-mau-q7-52m2-4-tang-nhinh-10-ty/294183
# ---------------------------------------------
# https://nhadat24h.net.vn/du-an/dan0403-hoang-trong-mau-q7-52m2-4-tang-nhinh-10-ty/295042
# +++++++++++++++++++++++++++++++++++++++++++++
# https://alonhadat.com.vn/-hem-xe-tai-tranh-79m2-ngang-6m-3-tang-nha-moi-noi-that-sin-so-le-duc-tho-13825761.html
# ---------------------------------------------
# https://alonhadat.com.vn/hem-xe-tai-tranh-79m2-ngang-6m-3-tang-nha-moi-noi-that-sin-so-le-duc-tho-13825755.html
# +++++++++++++++++++++++++++++++++++++++++++++
# https://bds123.vn/ban-nha-chung-cu-mi-ni-duong-lang-dong-da-94m-7-tang-mt-5-m-gia-16-ty-pr668112.html
# ---------------------------------------------
# https://bds123.vn/ban-nha-chung-cu-mi-ni-duong-lang-dong-da-94m-7-tang-mt-5m-gia-16-ty-pr671419.html
# +++++++++++++++++++++++++++++++++++++++++++++
# ...

# %%
delete_data = dataset.iloc[matches.index.unique(1)]['title']
delete_data = delete_data.reset_index()

# %%
delete_data
# Out:
#      index                                              title
# 0    19759  DAN0403 - HOÀNG TRỌNG MẬU Q7 – 52M2 - 4 TẦNG –...
# 1        4  HẺM XE TẢI TRÁNH - 79M2 - NGANG 6M - 3 TẦNG - ...
# 2     3768  Bán nhà chung cư mi ni đường Láng, Đống Đa 94m...
# 3    19336  Bán căn hộ FPT Plaza 2pn Full Nội thất, sổ hồn...
# 4     1462  Bán Nhà riêng Phố Đại La - Ô tô - Kinh doanh đ...
# ..     ...                                                ...
# 155  19174  Xuất cảnh cần bán gấp đất vườn cây ăn trái 15 ...
# 156  19175  Cần bán gấp đất  2,1 mẫu tại huyện La Pa tỉnh ...
# 157  19408  Nhà đường Thích Quảng Đức VCN Phước Hải Nha Tr...
# 158  19457  Mới nhất O9 Z6Z8 5559 Bán nhà Võ Chí Công 457m...
# 159  20099  Chia gia tài cho con cần bán gấp nhà phố Xã Hò...
#
# [160 rows x 2 columns]

# %%
row_del = []
for i in matches.index.unique(1):
  row_del.append(i)

# %%
data_clean = dataset.drop(row_del)

# %%
data_clean = data_clean.reset_index(drop=True)

# %%
data_clean.to_csv("/content/drive/MyDrive/newcode/all_data_after_deduplication.csv", index=False, header=True)
